# %%
from IPython.display import Image
Image(filename='pictures/pokemon.png')

# %%
import pandas as pd 
pokemon_df = pd.read_csv("pokemon.csv")
pokemon_df
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
#  How to create a Dataframe?
data = {"Name": ["Bulbasaur", "Ivysaur", "Venusaur"], 
        "Type 1": ["Grass", "Grass", "Grass"],
        "Attack": [49, 62, 82]}
pd.DataFrame(data)
# Out:
#    Attack       Name Type 1
# 0      49  Bulbasaur  Grass
# 1      62    Ivysaur  Grass
# 2      82   Venusaur  Grass

# %% [markdown]
# ## Basic Information

# %%
# Shape of pandas dataframe
pokemon_df.shape
# Out:
# Shape:
# (800, 13)

# %%
# Name of columns
pokemon_df.columns
# Out:
# Columns:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Information on the type of data per column
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# ## Subselection

# %%
# First lines
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack2  Power
# 0       65       65     45           1      False       98      0
# 1       80       80     60           1      False      124     -1
# 2      100      100     80           1      False      164     -1
# 3      122      120     80           1      False      200    -23
# 4       60       50     65           1      False      104      9

# %%
# Selecting rows
pokemon_df[10:15]
# Out:
#      #                     Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 10   8                Wartortle  Water    NaN    405  59      63       80
# 11   9                Blastoise  Water    NaN    530  79      83      100
# 12   9  BlastoiseMega Blastoise  Water    NaN    630  79     103      120
# 13  10                 Caterpie    Bug    NaN    195  45      30       35
# 14  11                  Metapod    Bug    NaN    205  50      20       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack2  Power
# 10       65       80     58           1      False      126    -17
# 11       85      105     78           1      False      166    -17
# 12      135      115     78           1      False      206    -17
# 13       20       20     45           1      False       60     -5
# 14       25       25     30           1      False       40    -35

# %%
# Selecting one column  (A series)
pokemon_df["Attack"]
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 4       52
# 5       64
# 6       84
# 7      130
# 8      104
# 9       48
# 10      63
# 11      83
# 12     103
# 13      30
# 14      20
# 15      45
# 16      35
# 17      25
# 18      90
# 19     150
# 20      45
# 21      60
# 22      80
# 23      80
# 24      56
# 25      81
# 26      60
# 27      90
# 28      60
# 29      85
#       ...
# 770     65
# 771     92
# 772     58
# 773     50
# 774     50
# 775     75
# 776    100
# 777     80
# 778     70
# 779    110
# 780     66
# 781     66
# 782     66
# 783     66
# 784     90
# 785     85
# 786     95
# 787    100
# 788     69
# 789    117
# 790     30
# 791     70
# 792    131
# 793    131
# 794    100
# 795    100
# 796    160
# 797    110
# 798    160
# 799    110
# Name: Attack, Length: 800, dtype: int64

# %%
# Selecting more than one column
pokemon_df[["Attack", "Defense", "Speed"]].head()
# Out:
#    Attack  Defense  Speed
# 0      49       49     45
# 1      62       63     60
# 2      82       83     80
# 3     100      123     80
# 4      52       43     65

# %%
# Removing rows
pokemon_df.drop([1,2,3]).head()
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False

# %%
# Removing columns
pokemon_df.drop(["Type 2", "Generation"], axis=1).head()
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Legendary
# 0       65     45      False
# 1       80     60      False
# 2      100     80      False
# 3      120     80      False
# 4       50     65      False

# %%
# Filtering
pokemon_df[pokemon_df["Attack"]>180]
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 232      115       40      105     75           2      False

# %%
# Filtering top n largest
pokemon_df.nlargest(5, "Attack")
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 232      115       40      105     75           2      False
# 424      160      150       90     90           3       True
# 426      100      180      100    115           3       True
# 429       20      180       20    150           3       True

# %%
# Sorting by attack
pokemon_df.sort_values(by="Attack", ascending=False).head()
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 232      115       40      105     75           2      False
# 424      160      150       90     90           3       True
# 426      100      180      100    115           3       True
# 429       20      180       20    150           3       True

# %% [markdown]
# ## Analizing the Dataframe

# %%
pokemon_df.sum()
# Out:
# #             362.81375
# Total         435.10250
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
pokemon_df.mean()
# Out:
# #             362.81375
# Total         435.10250
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
pokemon_df["Attack"].mean()
# Out:
# 79.00125

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# ## Operations between columns

# %%
# Functions between columns
pokemon_df["Power"] = pokemon_df["Attack"] - pokemon_df["Defense"] 
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack2  Power
# 0       65       65     45           1      False       98      0
# 1       80       80     60           1      False      124     -1
# 2      100      100     80           1      False      164     -1
# 3      122      120     80           1      False      200    -23
# 4       60       50     65           1      False      104      9

# %%
# Functions working on columns to create a new column
pokemon_df["Attack2"] = pokemon_df["Attack"] * 2
pokemon_df.head()
# For more complicated functions, use lambda functions
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack2  Power
# 0       65       65     45           1      False       98      0
# 1       80       80     60           1      False      124     -1
# 2      100      100     80           1      False      164     -1
# 3      122      120     80           1      False      200    -23
# 4       60       50     65           1      False      104      9
